# %% [markdown]
# # INTRODUCTION TO PYTHON
#
# - CAT IS FRIENDLY
# - DOG IS BLACK
# ![Thank%20you.png](attachment:Thank%20you.png)

# %%
s="10"
type(s)
# Out:
# str

# %%
s=2.04
print(s)
type(s)
# Out:
# 2.04
# float

# %%
c=4+55j
type(c)
# Out:
# complex

# %%
a=10
b=5
if a>b:
    print('a is greater')    
else:
    print('b is greater')
# Out:
# a is greater

# %%
aman123=76
type(aman123)
# Out:
# int

# %%
123aman=555
type(123aman)
# Out:
#   File "<ipython-input-6-b353bed3c828>", line 1
#     123aman=555
#        ^
# SyntaxError: invalid syntax

# %%
am123an=555
type(am123an)
# Out:
# int

# %%
@aman=123
type(@aman)
# Out:
#   File "<ipython-input-8-2941230e1ce0>", line 1
#     @aman=123
#          ^
# SyntaxError: invalid syntax

# %%
aman@=10
type(aman@)
# Out:
#   File "<ipython-input-9-5738ec10674e>", line 2
#     type(aman@)
#               ^
# SyntaxError: invalid syntax

# %%
am@an=10
type(am@an)
# Out:
#   File "<ipython-input-10-157174247ff7>", line 1
#     am@an=10
#     ^
# SyntaxError: cannot assign to operator

# %%
_aman=10
type(_aman)
# Out:
# int

# %%
_123=10
type(_123)
# Out:
# int

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a=10
a=float(a)
print(a)
# Out:
# 10.0

# %%
a=str(a)

# %%
a
# Out:
# '10.0'

# %%
s=10
s=float(str(int(float(int(str(s))))))

# %%
s
# Out:
# 10.0
