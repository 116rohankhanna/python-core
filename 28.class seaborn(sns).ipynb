# %% [markdown]
# stats base visualization (seaborn use )

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style="darkgrid") #for dark background

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="day");

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="day",size="sex");

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="day",size="sex",aspect=1,height=7); #for increasing heigth of graph or use figure

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="day",size="sex",style="time");

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="size",size="sex",style="time");

# %%
df=pd.read_csv("advertising.csv",index_col=0)
df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
sns.relplot(x="TV",y="sales",data=df);
sns.relplot(x="radio",y="sales",data=df);
sns.relplot(x="newspaper",y="sales",data=df);

# %%
sns.pairplot(df);

# %%
sns.barplot(x='day',y='tip',data=tips,hue='sex');

# %%
sns.boxplot(x='day',y='total_bill',data=tips);

# %%
a=np.array([[1,2,3],[4,5,6]])
a.cumsum() #cumsum use as fabonics series
# Out:
# array([ 1,  3,  6, 10, 15, 21], dtype=int32)

# %%
df1=sns.load_dataset("fmri")
df1
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x='timepoint',y='signal',ci=False,data=df1);

# %%
#hue,style try at home

# %%
sns.lineplot(x='timepoint',y='signal',ci=False,data=df1,hue='region',style='event');

# %%
sns.lineplot(x='timepoint',y='signal',ci=False,data=df1,hue='region',style='event',markers=True); #markers is used to represents line..

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='time',data=tips) #col

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',row='time',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',row='time',col='sex',data=tips); #row

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='day',col_wrap=2,data=tips) #col_wrap take 2 column in parallel and other by down

# %% [markdown]
# # catergorical data ploting

# %%
sns.catplot(y='total_bill',x='day',hue='time',data=tips);

# %%
sns.catplot(y='total_bill',x='day',data=tips,jitter=False);

# %%
sns.catplot(y='tip',x='day',data=tips,kind='swarm',height=7);

# %%
sns.catplot(x='day',y='tip',kind='box',data=tips,hue='sex');

# %%
a=sns.load_dataset("diamonds")
a
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
a.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x='cut',y='price',data=a,kind='boxen',palette=['red','blue','yellow','green','black']);

# %% [markdown]
# # violin chart

# %%
sns.catplot(x='day',y='total_bill',hue='sex',kind='violin',data=tips);

# %%
g=sns.catplot(x='day',y='tip',kind='violin',inner=None,data=tips);
sns.swarmplot(x='day',y='tip',color='k',size=3,data=tips,ax=g.ax);

# %% [markdown]
# # distribution plot

# %%
sns.distplot(tips["tip"]);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips["total_bill"],kde=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# # jointplot

# %%
sns.jointplot(x=tips["total_bill"],y=tips["tip"],kind="kde");

# %%
sns.lmplot(x="TV",y='sales',data=df);

# %%
sns.regplot(x="TV",y='sales',data=df,);
